# %%
# Import the random module.
import random
# Import linear regression from the SciPy stats module.
from scipy.stats import linregress
# Import the NumPy module.
import numpy as np
# Import timeit.
import timeit
#Import citipy
from citipy import citipy
#Import the requests library.
import requests
# Import the API key.
from Config import weather_api_key
import pandas as pd
from datetime import datetime

# %%
#Create a new set of 2,000 random latitudes and longitudes.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
def latitudes(size):
    latitudes = []
    x = 0
    while x < (size):
        random_lat = random.randint(-90, 90) + random.random()
        latitudes.append(random_lat)
        x += 1
    return latitudes
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
print(city)
# Out:
# koppal

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# Create an endpoint URL for a city.
city_url = url + "&q=" + "yellowknife"
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ee9f372996f842aba60e803cacce7764&q=yellowknife

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"
# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
# Run an API request for each of the cities.
    try:
    # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
    # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_description = city_weather["weather"][0]["description"]
    # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Weather Description": city_description})

# If an error is experienced, skip the city.
    except Exception as e:
        print(e)
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 16 | airai
# Processing Record 2 of Set 16 | palmer
# Processing Record 3 of Set 16 | khatanga
# Processing Record 4 of Set 16 | marcona
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 16 | alofi
# Processing Record 6 of Set 16 | kodiak
# Processing Record 7 of Set 16 | kruisfontein
# Processing Record 8 of Set 16 | pleasanton
# Processing Record 9 of Set 16 | buchanan
# Processing Record 10 of Set 16 | sao filipe
# Processing Record 11 of Set 16 | puerto ayora
# Processing Record 12 of Set 16 | mataura
# Processing Record 13 of Set 16 | castro
# Processing Record 14 of Set 16 | kapaa
# Processing Record 15 of Set 16 | dikson
# Processing Record 16 of Set 16 | illoqqortoormiut
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 16 | puerto colombia
# Processing Record 18 of Set 16 | tambacounda
# Processing Record 19 of Set 16 | new norfolk
# Processing Record 20 of Set 16 | saleaula
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 16 | sentyabrskiy
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 16 | ostrovnoy
# Processing Record 23 of Set 16 | dhemaji
# Processing Record 24 of Set 16 | lompoc
# Processing Record 25 of Set 16 | kazalinsk
# 'coord'
# City not found. Skipping...
# Processing Record 26 of Set 16 | jamestown
# Processing Record 27 of Set 16 | plettenberg bay
# Processing Record 28 of Set 16 | busselton
# Processing Record 29 of Set 16 | kavaratti
# Processing Record 30 of Set 16 | kapit
# Processing Record 31 of Set 16 | hithadhoo
# Processing Record 32 of Set 16 | hobart
# Processing Record 33 of Set 16 | esperance
# Processing Record 34 of Set 16 | great falls
# Processing Record 35 of Set 16 | longyearbyen
# Processing Record 36 of Set 16 | xai-xai
# Processing Record 37 of Set 16 | rikitea
# Processing Record 38 of Set 16 | arraial do cabo
# Processing Record 39 of Set 16 | ketchikan
# Processing Record 40 of Set 16 | saraland
# Processing Record 41 of Set 16 | port elizabeth
# Processing Record 42 of Set 16 | vao
# Processing Record 43 of Set 16 | meulaboh
# Processing Record 44 of Set 16 | noumea
# Processing Record 45 of Set 16 | sucua
# Processing Record 46 of Set 16 | cherskiy
# Processing Record 47 of Set 16 | amderma
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 16 | haines junction
# Processing Record 49 of Set 16 | tigil
# Processing Record 50 of Set 16 | inderborskiy
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 17 | saint-philippe
# Processing Record 2 of Set 17 | avarua
# Processing Record 3 of Set 17 | nikolskoye
# Processing Record 4 of Set 17 | yellowknife
# Processing Record 5 of Set 17 | chokurdakh
# Processing Record 6 of Set 17 | xudat
# Processing Record 7 of Set 17 | east london
# Processing Record 8 of Set 17 | chuy
# Processing Record 9 of Set 17 | banjar
# Processing Record 10 of Set 17 | kem
# Processing Record 11 of Set 17 | ginir
# Processing Record 12 of Set 17 | ribeira grande
# Processing Record 13 of Set 17 | asau
# Processing Record 14 of Set 17 | butaritari
# Processing Record 15 of Set 17 | oksfjord
# Processing Record 16 of Set 17 | ruatoria
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 17 | cayenne
# Processing Record 18 of Set 17 | vila velha
# Processing Record 19 of Set 17 | juneau
# Processing Record 20 of Set 17 | tabukiniberu
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 17 | yelatma
# Processing Record 22 of Set 17 | nelson bay
# Processing Record 23 of Set 17 | tiksi
# Processing Record 24 of Set 17 | nuevo progreso
# Processing Record 25 of Set 17 | upernavik
# Processing Record 26 of Set 17 | thompson
# Processing Record 27 of Set 17 | kloulklubed
# Processing Record 28 of Set 17 | vaitupu
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 17 | ondjiva
# Processing Record 30 of Set 17 | punta arenas
# Processing Record 31 of Set 17 | pangnirtung
# Processing Record 32 of Set 17 | chokwe
# Processing Record 33 of Set 17 | vaini
# Processing Record 34 of Set 17 | lolua
# 'coord'
# City not found. Skipping...
# Processing Record 35 of Set 17 | albany
# Processing Record 36 of Set 17 | eureka
# Processing Record 37 of Set 17 | ushuaia
# Processing Record 38 of Set 17 | radstadt
# Processing Record 39 of Set 17 | doljo
# Processing Record 40 of Set 17 | bilibino
# Processing Record 41 of Set 17 | lisala
# Processing Record 42 of Set 17 | ilulissat
# Processing Record 43 of Set 17 | adrar
# Processing Record 44 of Set 17 | mar del plata
# Processing Record 45 of Set 17 | begoro
# Processing Record 46 of Set 17 | chikoy
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 17 | muros
# Processing Record 48 of Set 17 | hermanus
# Processing Record 49 of Set 17 | abha
# Processing Record 50 of Set 17 | bluff
# Processing Record 1 of Set 18 | inhambane
# Processing Record 2 of Set 18 | tasiilaq
# Processing Record 3 of Set 18 | yarim
# Processing Record 4 of Set 18 | moussoro
# Processing Record 5 of Set 18 | newtonmore
# Processing Record 6 of Set 18 | dukat
# Processing Record 7 of Set 18 | buala
# Processing Record 8 of Set 18 | aneby
# Processing Record 9 of Set 18 | belaya gora
# Processing Record 10 of Set 18 | lewistown
# Processing Record 11 of Set 18 | saint george
# Processing Record 12 of Set 18 | pevek
# Processing Record 13 of Set 18 | shkotovo-22
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 18 | tsihombe
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 18 | cape town
# Processing Record 16 of Set 18 | lazaro cardenas
# Processing Record 17 of Set 18 | biak
# Processing Record 18 of Set 18 | launceston
# Processing Record 19 of Set 18 | palabuhanratu
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 18 | balkanabat
# Processing Record 21 of Set 18 | guerrero
# Processing Record 22 of Set 18 | torbay
# Processing Record 23 of Set 18 | severo-kurilsk
# Processing Record 24 of Set 18 | saint-joseph
# Processing Record 25 of Set 18 | aklavik
# Processing Record 26 of Set 18 | santa cruz
# Processing Record 27 of Set 18 | bengkulu
# Processing Record 28 of Set 18 | port alfred
# Processing Record 29 of Set 18 | beloha
# Processing Record 30 of Set 18 | dingle
# Processing Record 31 of Set 18 | karpathos
# Processing Record 32 of Set 18 | gizo
# Processing Record 33 of Set 18 | muslyumovo
# Processing Record 34 of Set 18 | bredasdorp
# Processing Record 35 of Set 18 | sars
# Processing Record 36 of Set 18 | lindi
# Processing Record 37 of Set 18 | constitucion
# Processing Record 38 of Set 18 | ponta do sol
# Processing Record 39 of Set 18 | kota kinabalu
# Processing Record 40 of Set 18 | alyangula
# Processing Record 41 of Set 18 | guerrero negro
# Processing Record 42 of Set 18 | hilo
# Processing Record 43 of Set 18 | karratha
# Processing Record 44 of Set 18 | kaniama
# Processing Record 45 of Set 18 | north bend
# Processing Record 46 of Set 18 | pakwach
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 18 | udachnyy
# Processing Record 48 of Set 18 | waipawa
# Processing Record 49 of Set 18 | touros
# Processing Record 50 of Set 18 | sneek
# Processing Record 1 of Set 19 | taolanaro
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 19 | baruun-urt
# Processing Record 3 of Set 19 | leningradskiy
# Processing Record 4 of Set 19 | barrow
# Processing Record 5 of Set 19 | uwayl
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 19 | redmond
# Processing Record 7 of Set 19 | solano
# Processing Record 8 of Set 19 | tuktoyaktuk
# Processing Record 9 of Set 19 | lima
# Processing Record 10 of Set 19 | spencer
# Processing Record 11 of Set 19 | katsuura
# Processing Record 12 of Set 19 | jiddah
# 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 19 | rawson
# Processing Record 14 of Set 19 | sorvag
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 19 | nanortalik
# Processing Record 16 of Set 19 | keita
# Processing Record 17 of Set 19 | nalut
# Processing Record 18 of Set 19 | salalah
# Processing Record 19 of Set 19 | mrirt
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 19 | mount gambier
# Processing Record 21 of Set 19 | kirakira
# Processing Record 22 of Set 19 | almaznyy
# Processing Record 23 of Set 19 | rio grande
# Processing Record 24 of Set 19 | codrington
# Processing Record 25 of Set 19 | carnarvon
# Processing Record 26 of Set 19 | saskylakh
# Processing Record 27 of Set 19 | qaanaaq
# Processing Record 28 of Set 19 | ust-kut
# Processing Record 29 of Set 19 | itaituba
# Processing Record 30 of Set 19 | pocatello
# Processing Record 31 of Set 19 | dzaoudzi
# Processing Record 32 of Set 19 | cidreira
# Processing Record 33 of Set 19 | ancud
# Processing Record 34 of Set 19 | homer
# Processing Record 35 of Set 19 | ghanzi
# Processing Record 36 of Set 19 | santa cruz cabralia
# Processing Record 37 of Set 19 | sioux lookout
# Processing Record 38 of Set 19 | makasar
# Processing Record 39 of Set 19 | barawe
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 19 | sobral
# Processing Record 41 of Set 19 | grand river south east
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 19 | souillac
# Processing Record 43 of Set 19 | pilar
# Processing Record 44 of Set 19 | mahon
# Processing Record 45 of Set 19 | hambantota
# Processing Record 46 of Set 19 | malinovoye ozero
# Processing Record 47 of Set 19 | gallup
# Processing Record 48 of Set 19 | san patricio
# Processing Record 49 of Set 19 | tuatapere
# Processing Record 50 of Set 19 | chapais
# Processing Record 1 of Set 20 | teguldet
# Processing Record 2 of Set 20 | saldanha
# Processing Record 3 of Set 20 | quatre cocos
# Processing Record 4 of Set 20 | camamu
# Processing Record 5 of Set 20 | husavik
# Processing Record 6 of Set 20 | jati
# Processing Record 7 of Set 20 | bandarbeyla
# Processing Record 8 of Set 20 | camocim
# Processing Record 9 of Set 20 | kristiinankaupunki
# Processing Record 10 of Set 20 | kangalassy
# Processing Record 11 of Set 20 | jalu
# Processing Record 12 of Set 20 | charlestown
# Processing Record 13 of Set 20 | isla mujeres
# Processing Record 14 of Set 20 | melilla
# Processing Record 15 of Set 20 | clyde river
# Processing Record 16 of Set 20 | san andres
# Processing Record 17 of Set 20 | rio gallegos
# Processing Record 18 of Set 20 | saint-augustin
# Processing Record 19 of Set 20 | cabo san lucas
# Processing Record 20 of Set 20 | ngunguru
# Processing Record 21 of Set 20 | burica
# 'coord'
# City not found. Skipping...
# Processing Record 22 of Set 20 | vardo
# Processing Record 23 of Set 20 | shu
# Processing Record 24 of Set 20 | kiama
# Processing Record 25 of Set 20 | champerico
# Processing Record 26 of Set 20 | crotone
# Processing Record 27 of Set 20 | bathsheba
# Processing Record 28 of Set 20 | namatanai
# Processing Record 29 of Set 20 | vilyuysk
# Processing Record 30 of Set 20 | porlamar
# Processing Record 31 of Set 20 | korla
# Processing Record 32 of Set 20 | banyo
# Processing Record 33 of Set 20 | misratah
# Processing Record 34 of Set 20 | faanui
# Processing Record 35 of Set 20 | bahia blanca
# Processing Record 36 of Set 20 | lorengau
# Processing Record 37 of Set 20 | half moon bay
# Processing Record 38 of Set 20 | bayan
# Processing Record 39 of Set 20 | kutum
# Processing Record 40 of Set 20 | kavieng
# Processing Record 41 of Set 20 | odesskoye
# Processing Record 42 of Set 20 | prince rupert
# Processing Record 43 of Set 20 | kolondieba
# Processing Record 44 of Set 20 | fortuna
# Processing Record 45 of Set 20 | pisco
# Processing Record 46 of Set 20 | berlevag
# Processing Record 47 of Set 20 | flinders
# Processing Record 48 of Set 20 | winnemucca
# Processing Record 49 of Set 20 | almansa
# Processing Record 50 of Set 20 | oranjemund
# Processing Record 1 of Set 21 | merritt island
# Processing Record 2 of Set 21 | leh
# Processing Record 3 of Set 21 | longfeng
# Processing Record 4 of Set 21 | hervey bay
# Processing Record 5 of Set 21 | lavrentiya
# Processing Record 6 of Set 21 | tumannyy
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 21 | atuona
# Processing Record 8 of Set 21 | barcelos
# Processing Record 9 of Set 21 | koshurnikovo
# Processing Record 10 of Set 21 | gavrilovka vtoraya
# Processing Record 11 of Set 21 | magadan
# Processing Record 12 of Set 21 | santa eulalia del rio
# 'coord'
# City not found. Skipping...
# Processing Record 13 of Set 21 | slanic-moldova
# Processing Record 14 of Set 21 | margate
# Processing Record 15 of Set 21 | sataua
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 21 | stykkisholmur
# Processing Record 17 of Set 21 | umzimvubu
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 21 | karaul
# 'coord'
# City not found. Skipping...
# Processing Record 19 of Set 21 | tiznit
# Processing Record 20 of Set 21 | westport
# Processing Record 21 of Set 21 | golden
# Processing Record 22 of Set 21 | dangriga
# Processing Record 23 of Set 21 | kualakapuas
# Processing Record 24 of Set 21 | bambous virieux
# Processing Record 25 of Set 21 | saint anthony
# Processing Record 26 of Set 21 | arlit
# Processing Record 27 of Set 21 | listvyanka
# Processing Record 28 of Set 21 | marilia
# Processing Record 29 of Set 21 | provideniya
# Processing Record 30 of Set 21 | baykit
# Processing Record 31 of Set 21 | erenhot
# Processing Record 32 of Set 21 | ulladulla
# Processing Record 33 of Set 21 | atambua
# Processing Record 34 of Set 21 | komsomolskiy
# Processing Record 35 of Set 21 | vigrestad
# Processing Record 36 of Set 21 | meadow lake
# Processing Record 37 of Set 21 | martapura
# Processing Record 38 of Set 21 | oktyabrskiy
# Processing Record 39 of Set 21 | betsiamites
# Processing Record 40 of Set 21 | raga
# Processing Record 41 of Set 21 | bay roberts
# Processing Record 42 of Set 21 | walvis bay
# Processing Record 43 of Set 21 | bethel
# Processing Record 44 of Set 21 | mys shmidta
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 21 | bandar-e lengeh
# Processing Record 46 of Set 21 | hofn
# Processing Record 47 of Set 21 | qaqortoq
# Processing Record 48 of Set 21 | mbini
# Processing Record 49 of Set 21 | kantang
# Processing Record 50 of Set 21 | broken hill
# Processing Record 1 of Set 22 | kazbegi
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 22 | port lincoln
# Processing Record 3 of Set 22 | mayumba
# Processing Record 4 of Set 22 | goderich
# Processing Record 5 of Set 22 | san quintin
# Processing Record 6 of Set 22 | belushya guba
# 'coord'
# City not found. Skipping...
# Processing Record 7 of Set 22 | waingapu
# Processing Record 8 of Set 22 | santiago del estero
# Processing Record 9 of Set 22 | rocha
# Processing Record 10 of Set 22 | winsum
# Processing Record 11 of Set 22 | cockburn town
# Processing Record 12 of Set 22 | ayaviri
# Processing Record 13 of Set 22 | yeniseysk
# Processing Record 14 of Set 22 | aswan
# Processing Record 15 of Set 22 | svelgen
# Processing Record 16 of Set 22 | vostok
# Processing Record 17 of Set 22 | tanout
# Processing Record 18 of Set 22 | bambanglipuro
# Processing Record 19 of Set 22 | mahebourg
# Processing Record 20 of Set 22 | chyhyryn
# Processing Record 21 of Set 22 | maracacume
# Processing Record 22 of Set 22 | delta
# Processing Record 23 of Set 22 | nassau
# Processing Record 24 of Set 22 | gewane
# Processing Record 25 of Set 22 | viljoenskroon
# Processing Record 26 of Set 22 | dakar
# Processing Record 27 of Set 22 | buraydah
# Processing Record 28 of Set 22 | ahuimanu
# Processing Record 29 of Set 22 | gushi
# Processing Record 30 of Set 22 | kawalu
# Processing Record 31 of Set 22 | college
# Processing Record 32 of Set 22 | barentsburg
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 22 | minab
# Processing Record 34 of Set 22 | broome
# Processing Record 35 of Set 22 | beringovskiy
# Processing Record 36 of Set 22 | balabac
# Processing Record 37 of Set 22 | alice springs
# Processing Record 38 of Set 22 | hit
# Processing Record 39 of Set 22 | yanliang
# Processing Record 40 of Set 22 | pahrump
# Processing Record 41 of Set 22 | gulshat
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 22 | amantea
# Processing Record 43 of Set 22 | sibolga
# Processing Record 44 of Set 22 | mahanoro
# Processing Record 45 of Set 22 | ponta delgada
# Processing Record 46 of Set 22 | iqaluit
# Processing Record 47 of Set 22 | nemuro
# Processing Record 48 of Set 22 | lugovoy
# Processing Record 49 of Set 22 | cap-aux-meules
# Processing Record 50 of Set 22 | vaitape
# Processing Record 1 of Set 23 | atsiki
# 'coord'
# City not found. Skipping...
# Processing Record 2 of Set 23 | palana
# Processing Record 3 of Set 23 | lundazi
# Processing Record 4 of Set 23 | kuche
# 'coord'
# City not found. Skipping...
# Processing Record 5 of Set 23 | baherden
# Processing Record 6 of Set 23 | krasnoselkup
# Processing Record 7 of Set 23 | mahajanga
# Processing Record 8 of Set 23 | lokachi
# Processing Record 9 of Set 23 | bequimao
# Processing Record 10 of Set 23 | rudnogorsk
# Processing Record 11 of Set 23 | ocos
# Processing Record 12 of Set 23 | kupang
# Processing Record 13 of Set 23 | camacha
# Processing Record 14 of Set 23 | sahrak
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 23 | lebu
# Processing Record 16 of Set 23 | shetpe
# Processing Record 17 of Set 23 | samusu
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 23 | narkanda
# Processing Record 19 of Set 23 | solnechnyy
# Processing Record 20 of Set 23 | freehold
# Processing Record 21 of Set 23 | concepcion
# Processing Record 22 of Set 23 | zarechnyy
# Processing Record 23 of Set 23 | srednekolymsk
# Processing Record 24 of Set 23 | south venice
# Processing Record 25 of Set 23 | ilam
# Processing Record 26 of Set 23 | wukari
# Processing Record 27 of Set 23 | charters towers
# Processing Record 28 of Set 23 | caravelas
# Processing Record 29 of Set 23 | isangel
# Processing Record 30 of Set 23 | pervomayskoye
# Processing Record 31 of Set 23 | kaitangata
# Processing Record 32 of Set 23 | abiy adi
# 'coord'
# City not found. Skipping...
# Processing Record 33 of Set 23 | umm kaddadah
# Processing Record 34 of Set 23 | srandakan
# Processing Record 35 of Set 23 | puerto escondido
# Processing Record 36 of Set 23 | hasaki
# Processing Record 37 of Set 23 | nouakchott
# Processing Record 38 of Set 23 | katha
# 'coord'
# City not found. Skipping...
# Processing Record 39 of Set 23 | cochrane
# Processing Record 40 of Set 23 | okhotsk
# Processing Record 41 of Set 23 | mogadishu
# Processing Record 42 of Set 23 | anadyr
# Processing Record 43 of Set 23 | toliary
# 'coord'
# City not found. Skipping...
# Processing Record 44 of Set 23 | sarkand
# Processing Record 45 of Set 23 | coahuayana
# Processing Record 46 of Set 23 | yar-sale
# Processing Record 47 of Set 23 | sovetskiy
# Processing Record 48 of Set 23 | berdigestyakh
# Processing Record 49 of Set 23 | henties bay
# Processing Record 50 of Set 23 | hualmay
# Processing Record 1 of Set 24 | salinas
# Processing Record 2 of Set 24 | mao
# Processing Record 3 of Set 24 | faya
# Processing Record 4 of Set 24 | sabzevar
# Processing Record 5 of Set 24 | safwah
# 'coord'
# City not found. Skipping...
# Processing Record 6 of Set 24 | pokrovo-prigorodnoye
# Processing Record 7 of Set 24 | sayyan
# Processing Record 8 of Set 24 | riaba
# 'coord'
# City not found. Skipping...
# Processing Record 9 of Set 24 | paamiut
# Processing Record 10 of Set 24 | bethanien
# Processing Record 11 of Set 24 | abu jubayhah
# 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 24 | prado
# Processing Record 13 of Set 24 | port blair
# Processing Record 14 of Set 24 | novoyegoryevskoye
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 24 | kansk
# Processing Record 16 of Set 24 | la rioja
# Processing Record 17 of Set 24 | chagda
# 'coord'
# City not found. Skipping...
# Processing Record 18 of Set 24 | tadine
# Processing Record 19 of Set 24 | palaia fokaia
# Processing Record 20 of Set 24 | sun city west
# Processing Record 21 of Set 24 | manyana
# Processing Record 22 of Set 24 | dalvik
# Processing Record 23 of Set 24 | port keats
# Processing Record 24 of Set 24 | alcudia
# Processing Record 25 of Set 24 | bac lieu
# Processing Record 26 of Set 24 | saint-jean-de-braye
# Processing Record 27 of Set 24 | hobyo
# Processing Record 28 of Set 24 | narsaq
# Processing Record 29 of Set 24 | kabalo
# Processing Record 30 of Set 24 | laguna
# Processing Record 31 of Set 24 | ingham
# Processing Record 32 of Set 24 | victoria
# Processing Record 33 of Set 24 | ipixuna
# Processing Record 34 of Set 24 | nantucket
# Processing Record 35 of Set 24 | samarai
# Processing Record 36 of Set 24 | sitka
# Processing Record 37 of Set 24 | el pinon
# Processing Record 38 of Set 24 | gra liyia
# Processing Record 39 of Set 24 | rungata
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 24 | brigantine
# Processing Record 41 of Set 24 | koungheul
# Processing Record 42 of Set 24 | changtu
# Processing Record 43 of Set 24 | kushima
# Processing Record 44 of Set 24 | sao borja
# Processing Record 45 of Set 24 | la asuncion
# Processing Record 46 of Set 24 | terra santa
# Processing Record 47 of Set 24 | port hardy
# Processing Record 48 of Set 24 | eyemouth
# Processing Record 49 of Set 24 | tecoanapa
# Processing Record 50 of Set 24 | price
# Processing Record 1 of Set 25 | tilichiki
# Processing Record 2 of Set 25 | okandja
# 'coord'
# City not found. Skipping...
# Processing Record 3 of Set 25 | jiayuguan
# Processing Record 4 of Set 25 | tursunzoda
# Processing Record 5 of Set 25 | betafo
# Processing Record 6 of Set 25 | linqiong
# Processing Record 7 of Set 25 | port macquarie
# Processing Record 8 of Set 25 | makakilo city
# Processing Record 9 of Set 25 | baoqing
# Processing Record 10 of Set 25 | kiunga
# Processing Record 11 of Set 25 | nizhneyansk
# 'coord'
# City not found. Skipping...
# Processing Record 12 of Set 25 | inuvik
# Processing Record 13 of Set 25 | tonj
# Processing Record 14 of Set 25 | coihaique
# Processing Record 15 of Set 25 | nishihara
# Processing Record 16 of Set 25 | russell
# Processing Record 17 of Set 25 | acapulco
# Processing Record 18 of Set 25 | tyret pervaya
# Processing Record 19 of Set 25 | the valley
# Processing Record 20 of Set 25 | atasu
# Processing Record 21 of Set 25 | ushtobe
# Processing Record 22 of Set 25 | geraldton
# Processing Record 23 of Set 25 | goundam
# Processing Record 24 of Set 25 | fairbanks
# Processing Record 25 of Set 25 | matara
# Processing Record 26 of Set 25 | tsabong
# Processing Record 27 of Set 25 | kargasok
# Processing Record 28 of Set 25 | bogorodskoye
# Processing Record 29 of Set 25 | talnakh
# Processing Record 30 of Set 25 | vohibinany
# Processing Record 31 of Set 25 | longyan
# Processing Record 32 of Set 25 | lata
# Processing Record 33 of Set 25 | roma
# Processing Record 34 of Set 25 | bourail
# Processing Record 35 of Set 25 | pesaro
# Processing Record 36 of Set 25 | riyadh
# Processing Record 37 of Set 25 | kungurtug
# Processing Record 38 of Set 25 | raudeberg
# Processing Record 39 of Set 25 | banda aceh
# Processing Record 40 of Set 25 | castrillon
# Processing Record 41 of Set 25 | ternate
# Processing Record 42 of Set 25 | tautira
# Processing Record 43 of Set 25 | hongjiang
# Processing Record 44 of Set 25 | vadso
# Processing Record 45 of Set 25 | georgetown
# Processing Record 46 of Set 25 | ucluelet
# Processing Record 47 of Set 25 | labuhan
# Processing Record 48 of Set 25 | teya
# Processing Record 49 of Set 25 | kytlym
# 'coord'
# City not found. Skipping...
# Processing Record 50 of Set 25 | kangaatsiaq
# Processing Record 1 of Set 26 | yilan
# Processing Record 2 of Set 26 | sorland
# Processing Record 3 of Set 26 | qasigiannguit
# Processing Record 4 of Set 26 | senneterre
# Processing Record 5 of Set 26 | satuk
# Processing Record 6 of Set 26 | praya
# Processing Record 7 of Set 26 | doha
# Processing Record 8 of Set 26 | tessalit
# Processing Record 9 of Set 26 | male
# Processing Record 10 of Set 26 | sokoni
# Processing Record 11 of Set 26 | palu
# Processing Record 12 of Set 26 | ascension
# Processing Record 13 of Set 26 | saint-pierre
# Processing Record 14 of Set 26 | river falls
# Processing Record 15 of Set 26 | big spring
# Processing Record 16 of Set 26 | tiarei
# Processing Record 17 of Set 26 | batagay-alyta
# Processing Record 18 of Set 26 | pueblo nuevo
# Processing Record 19 of Set 26 | poronaysk
# Processing Record 20 of Set 26 | swift current
# Processing Record 21 of Set 26 | fare
# Processing Record 22 of Set 26 | nabire
# Processing Record 23 of Set 26 | maryborough
# Processing Record 24 of Set 26 | meybod
# Processing Record 25 of Set 26 | norman wells
# Processing Record 26 of Set 26 | contamana
# Processing Record 27 of Set 26 | vila franca do campo
# Processing Record 28 of Set 26 | hunza
# 'coord'
# City not found. Skipping...
# Processing Record 29 of Set 26 | trapani
# Processing Record 30 of Set 26 | beisfjord
# Processing Record 31 of Set 26 | muzhi
# Processing Record 32 of Set 26 | savyntsi
# Processing Record 33 of Set 26 | santa rosa
# Processing Record 34 of Set 26 | yenagoa
# Processing Record 35 of Set 26 | soyo
# Processing Record 36 of Set 26 | luderitz
# Processing Record 37 of Set 26 | altar
# Processing Record 38 of Set 26 | kieta
# Processing Record 39 of Set 26 | richards bay
# Processing Record 40 of Set 26 | omboue
# Processing Record 41 of Set 26 | iskateley
# Processing Record 42 of Set 26 | vestmannaeyjar
# Processing Record 43 of Set 26 | kurchum
# Processing Record 44 of Set 26 | takanabe
# Processing Record 45 of Set 26 | lere
# Processing Record 46 of Set 26 | tabialan
# 'coord'
# City not found. Skipping...
# Processing Record 47 of Set 26 | manokwari
# Processing Record 48 of Set 26 | nome
# Processing Record 49 of Set 26 | watsa
# Processing Record 50 of Set 26 | nhulunbuy
# Processing Record 1 of Set 27 | kununurra
# Processing Record 2 of Set 27 | vanavara
# Processing Record 3 of Set 27 | high level
# Processing Record 4 of Set 27 | petropavlovskoye
# Processing Record 5 of Set 27 | hoquiam
# Processing Record 6 of Set 27 | buenos aires
# Processing Record 7 of Set 27 | pasighat
# Processing Record 8 of Set 27 | marawi
# Processing Record 9 of Set 27 | balikpapan
# Processing Record 10 of Set 27 | licata
# Processing Record 11 of Set 27 | kismayo
# Processing Record 12 of Set 27 | denpasar
# Processing Record 13 of Set 27 | sault sainte marie
# Processing Record 14 of Set 27 | mount isa
# Processing Record 15 of Set 27 | karkaralinsk
# 'coord'
# City not found. Skipping...
# Processing Record 16 of Set 27 | phan rang
# 'coord'
# City not found. Skipping...
# Processing Record 17 of Set 27 | fort nelson
# Processing Record 18 of Set 27 | tazovskiy
# Processing Record 19 of Set 27 | nara
# Processing Record 20 of Set 27 | ndele
# Processing Record 21 of Set 27 | diapaga
# Processing Record 22 of Set 27 | itaberai
# Processing Record 23 of Set 27 | taoudenni
# Processing Record 24 of Set 27 | dunedin
# Processing Record 25 of Set 27 | binga
# Processing Record 26 of Set 27 | turka
# Processing Record 27 of Set 27 | paita
# Processing Record 28 of Set 27 | pontes e lacerda
# Processing Record 29 of Set 27 | tevaitoa
# Processing Record 30 of Set 27 | yanam
# Processing Record 31 of Set 27 | tambopata
# Processing Record 32 of Set 27 | long xuyen
# Processing Record 33 of Set 27 | dudinka
# Processing Record 34 of Set 27 | santa cruz de tenerife
# Processing Record 35 of Set 27 | tucuman
# Processing Record 36 of Set 27 | namibe
# Processing Record 37 of Set 27 | krasnogorskoye
# Processing Record 38 of Set 27 | wilson
# Processing Record 39 of Set 27 | nioki
# Processing Record 40 of Set 27 | boden
# Processing Record 41 of Set 27 | bila krynytsya
# Processing Record 42 of Set 27 | salgado
# Processing Record 43 of Set 27 | kondinskoye
# Processing Record 44 of Set 27 | hammerfest
# Processing Record 45 of Set 27 | port-gentil
# Processing Record 46 of Set 27 | tombouctou
# Processing Record 47 of Set 27 | havre-saint-pierre
# Processing Record 48 of Set 27 | linkou
# Processing Record 49 of Set 27 | uni
# Processing Record 50 of Set 27 | azimur
# 'coord'
# City not found. Skipping...
# Processing Record 1 of Set 28 | springdale
# Processing Record 2 of Set 28 | mazyr
# Processing Record 3 of Set 28 | gikongoro
# Processing Record 4 of Set 28 | yulara
# Processing Record 5 of Set 28 | portel
# Processing Record 6 of Set 28 | vancouver
# Processing Record 7 of Set 28 | bougouni
# Processing Record 8 of Set 28 | jumla
# Processing Record 9 of Set 28 | naftah
# 'coord'
# City not found. Skipping...
# Processing Record 10 of Set 28 | pont-a-mousson
# Processing Record 11 of Set 28 | placido de castro
# Processing Record 12 of Set 28 | poykovskiy
# Processing Record 13 of Set 28 | ngukurr
# 'coord'
# City not found. Skipping...
# Processing Record 14 of Set 28 | portland
# Processing Record 15 of Set 28 | sola
# Processing Record 16 of Set 28 | kudahuvadhoo
# Processing Record 17 of Set 28 | padang
# Processing Record 18 of Set 28 | kerchevskiy
# Processing Record 19 of Set 28 | ardistan
# 'coord'
# City not found. Skipping...
# Processing Record 20 of Set 28 | najran
# Processing Record 21 of Set 28 | kamenka
# Processing Record 22 of Set 28 | nioro
# Processing Record 23 of Set 28 | binzhou
# Processing Record 24 of Set 28 | shelburne
# Processing Record 25 of Set 28 | colac
# Processing Record 26 of Set 28 | parkes
# Processing Record 27 of Set 28 | changji
# Processing Record 28 of Set 28 | vanimo
# Processing Record 29 of Set 28 | teknaf
# Processing Record 30 of Set 28 | cap malheureux
# Processing Record 31 of Set 28 | grindavik
# Processing Record 32 of Set 28 | comodoro rivadavia
# Processing Record 33 of Set 28 | sao miguel
# Processing Record 34 of Set 28 | bahia honda
# Processing Record 35 of Set 28 | palora
# Processing Record 36 of Set 28 | okha
# Processing Record 37 of Set 28 | tebingtinggi
# Processing Record 38 of Set 28 | egvekinot
# Processing Record 39 of Set 28 | turukhansk
# Processing Record 40 of Set 28 | galveston
# Processing Record 41 of Set 28 | la gaulette
# 'coord'
# City not found. Skipping...
# Processing Record 42 of Set 28 | trincomalee
# Processing Record 43 of Set 28 | zhezkazgan
# Processing Record 44 of Set 28 | attawapiskat
# 'coord'
# City not found. Skipping...
# Processing Record 45 of Set 28 | ampanihy
# Processing Record 46 of Set 28 | san jose de gracia
# Processing Record 47 of Set 28 | shubarkuduk
# Processing Record 48 of Set 28 | miri
# Processing Record 49 of Set 28 | quatis
# Processing Record 50 of Set 28 | sal rei
# Processing Record 1 of Set 29 | milkovo
# Processing Record 2 of Set 29 | khingansk
# Processing Record 3 of Set 29 | paka
# Processing Record 4 of Set 29 | puri
# Processing Record 5 of Set 29 | yining
# Processing Record 6 of Set 29 | edea
# Processing Record 7 of Set 29 | san pedro
# Processing Record 8 of Set 29 | bonavista
# Processing Record 9 of Set 29 | muisne
# Processing Record 10 of Set 29 | salinopolis
# Processing Record 11 of Set 29 | nouadhibou
# Processing Record 12 of Set 29 | mahibadhoo
# Processing Record 13 of Set 29 | beipiao
# Processing Record 14 of Set 29 | saint-marc
# Processing Record 15 of Set 29 | garissa
# Processing Record 16 of Set 29 | emerald
# Processing Record 17 of Set 29 | pafos
# Processing Record 18 of Set 29 | mayo
# Processing Record 19 of Set 29 | benicarlo
# Processing Record 20 of Set 29 | san policarpo
# Processing Record 21 of Set 29 | yerbogachen
# Processing Record 22 of Set 29 | gat
# Processing Record 23 of Set 29 | taltal
# Processing Record 24 of Set 29 | sile
# Processing Record 25 of Set 29 | te anau
# Processing Record 26 of Set 29 | bosaso
# Processing Record 27 of Set 29 | kenda
# Processing Record 28 of Set 29 | bilma
# Processing Record 29 of Set 29 | buon me thuot
# 'coord'
# City not found. Skipping...
# Processing Record 30 of Set 29 | waspan
# Processing Record 31 of Set 29 | mackenzie
# Processing Record 32 of Set 29 | bajil
# Processing Record 33 of Set 29 | fuxin
# Processing Record 34 of Set 29 | west wendover
# Processing Record 35 of Set 29 | port moresby
# Processing Record 36 of Set 29 | villa carlos paz
# Processing Record 37 of Set 29 | hoi an
# Processing Record 38 of Set 29 | alekseyevsk
# Processing Record 39 of Set 29 | pavullo nel frignano
# Processing Record 40 of Set 29 | nichinan
# Processing Record 41 of Set 29 | sabang
# Processing Record 42 of Set 29 | doka
# Processing Record 43 of Set 29 | sibi
# Processing Record 44 of Set 29 | tura
# Processing Record 45 of Set 29 | roald
# Processing Record 46 of Set 29 | sabha
# Processing Record 47 of Set 29 | ambodifototra
# 'coord'
# City not found. Skipping...
# Processing Record 48 of Set 29 | kourou
# Processing Record 49 of Set 29 | kambove
# Processing Record 50 of Set 29 | amparafaravola
# Processing Record 1 of Set 30 | bairiki
# Processing Record 2 of Set 30 | sao felix do xingu
# Processing Record 3 of Set 30 | ende
# Processing Record 4 of Set 30 | amga
# Processing Record 5 of Set 30 | susanino
# Processing Record 6 of Set 30 | pionerskiy
# Processing Record 7 of Set 30 | play cu
# 'coord'
# City not found. Skipping...
# Processing Record 8 of Set 30 | katesh
# Processing Record 9 of Set 30 | inta
# Processing Record 10 of Set 30 | siocon
# Processing Record 11 of Set 30 | vila
# Processing Record 12 of Set 30 | qobustan
# Processing Record 13 of Set 30 | klyuchevsk
# Processing Record 14 of Set 30 | tabiauea
# 'coord'
# City not found. Skipping...
# Processing Record 15 of Set 30 | general roca
# Processing Record 16 of Set 30 | lanzhou
# Processing Record 17 of Set 30 | knoxville
# Processing Record 18 of Set 30 | saquarema
# Processing Record 19 of Set 30 | san isidro
# Processing Record 20 of Set 30 | negele
# 'coord'
# City not found. Skipping...
# Processing Record 21 of Set 30 | kenora
# Processing Record 22 of Set 30 | maitum
# Processing Record 23 of Set 30 | gunjur
# Processing Record 24 of Set 30 | bumbuna
# Processing Record 25 of Set 30 | saint-georges
# Processing Record 26 of Set 30 | kysyl-syr
# Processing Record 27 of Set 30 | presidencia roque saenz pena
# Processing Record 28 of Set 30 | pemangkat
# Processing Record 29 of Set 30 | bohuslav
# Processing Record 30 of Set 30 | ambunti
# Processing Record 31 of Set 30 | cootamundra
# Processing Record 32 of Set 30 | skelleftea
# Processing Record 33 of Set 30 | ryotsu
# Processing Record 34 of Set 30 | axim
# Processing Record 35 of Set 30 | fort frances
# Processing Record 36 of Set 30 | umm lajj
# Processing Record 37 of Set 30 | ust-kamchatsk
# 'coord'
# City not found. Skipping...
# Processing Record 38 of Set 30 | verkhoyansk
# Processing Record 39 of Set 30 | gazni
# 'coord'
# City not found. Skipping...
# Processing Record 40 of Set 30 | carbonia
# Processing Record 41 of Set 30 | odweyne
# Processing Record 42 of Set 30 | gurgan
# 'coord'
# City not found. Skipping...
# Processing Record 43 of Set 30 | macapa
# Processing Record 44 of Set 30 | ossora
# Processing Record 45 of Set 30 | linhares
# Processing Record 46 of Set 30 | mikhaylovka
# Processing Record 47 of Set 30 | araouane
# Processing Record 48 of Set 30 | avera
# Processing Record 49 of Set 30 | amberley
# Processing Record 50 of Set 30 | conceicao do araguaia
# Processing Record 1 of Set 31 | kyaikto
# Processing Record 2 of Set 31 | porto novo
# Processing Record 3 of Set 31 | pochutla
# Processing Record 4 of Set 31 | poya
# Processing Record 5 of Set 31 | kimbe
# Processing Record 6 of Set 31 | diplo
# Processing Record 7 of Set 31 | ahipara
# Processing Record 8 of Set 31 | koppal
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0         Airai  -8.93  125.41     56.30        51          21        2.80
# 1        Palmer  42.16  -72.33     75.99        49          20        4.56
# 2      Khatanga  71.97  102.50     40.46        75           0        4.72
# 3         Alofi -19.06 -169.92     71.60        64          69       14.99
# 4        Kodiak  57.79 -152.41     53.60        93          90       21.92
# 5  Kruisfontein -34.00   24.73     61.00        79          25        5.99
# 6    Pleasanton  37.66 -121.87     82.99        43           1        2.08
# 7      Buchanan   5.88  -10.05     80.60        83          75        6.93
# 8    Sao Filipe  14.90  -24.50     78.39        79          77       10.71
# 9  Puerto Ayora  -0.74  -90.35     71.60        68          40       13.87
#
#   Weather Description
# 0          few clouds
# 1          few clouds
# 2           clear sky
# 3       broken clouds
# 4          light rain
# 5    scattered clouds
# 6                haze
# 7       broken clouds
# 8       broken clouds
# 9    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
